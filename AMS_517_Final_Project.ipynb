# %%
#only run it in google colab
from google.colab import drive
import os

drive.mount('/content/drive')

WORK_DIR = '/content/drive/MyDrive/AMS-517-Project'
if not os.path.exists(WORK_DIR):
    os.makedirs(WORK_DIR)

# %cd {WORK_DIR}

os.environ['PATH'] += ":/root/.cargo/bin"

print(f"Connect to the drive: {os.getcwd()}")
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/AMS-517-Project
# Connect to the drive: /content/drive/MyDrive/AMS-517-Project
